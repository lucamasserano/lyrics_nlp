# %%
import lyricsgenius # Genius lyrics provider API
from textblob import TextBlob # language detector
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
import logging
import sys
import re
import numpy as np
import time
import tqdm

# %% [markdown]
# ### Setup basic logging

# %%
logging.basicConfig(filename="/Users/lucamasserano/Desktop/BOCCONI/nlp/final_project/lyrics_project/log_files/lyrics_scraping_reversed.log",
                   level=logging.INFO,
                   format='%(asctime)s %(levelname)s %(message)s')

# %% [markdown]
# ### Functions for scraping artists and songs

# %%
def metrolyrics_retriever(output_df, 
                          driver, 
                          root_url="https://www.metrolyrics.com/top-artists.html", 
                          per_artist_limit=None, 
                          overall_limit=None):
    
    dataset = output_df
    alphabet, urls = retrieve_alphabet(root_url, driver)
    
    for letter, url in zip(alphabet, urls):
        
        artists = retrieve_artists(letter, url, driver)
        for artist, (artist_url, artist_genre) in artists.items():
            songs = retrieve_songs(artist, artist_url, driver, per_artist_limit=per_artist_limit)
            nans = [np.nan for i in range(len(songs))]
            genre = [artist_genre for i in range(len(songs))]
            
            artist_df = pd.DataFrame({"artist":[artist for i in range(len(songs))], 
                                      "song":songs, 
                                      "album":nans, 
                                      "release_date":nans, 
                                      "genre":genre, 
                                      "lyrics":nans})
            dataset = pd.concat([dataset, artist_df])
            dataset.reset_index(drop=True, inplace=True)
            
            
            print(f"\rSongs retrieved: {dataset.shape[0]}", end='\r')
            sys.stdout.flush()
            
            if not overall_limit is None:
                if dataset.shape[0] > overall_limit:
                    return dataset.iloc[:overall_limit, :]
        
        logging.info("Writing to csv")
        dataset.to_csv("/Users/lucamasserano/Desktop/BOCCONI/nlp/final_project/lyrics_project/songs.csv", index=False)
        
    return dataset

def retrieve_alphabet(url, driver):
    
    driver.get(url)
    html = driver.page_source
    logging.info("Alphabet html source loaded")
    soup = BeautifulSoup(html, "lxml")
    
    try:
        alphabet = soup.find("p", class_="artist-letters").find_all("a")
        letters = []
        urls = []
        for idx, letter in enumerate(alphabet):
            try:
                letter_text = letter.get_text()
                letter_url = letter.get("href")
                letters.append(letter_text)
                urls.append(letter_url)
            except AttributeError:
                logging.warning(f"Unable to retrieve artists for letter number {idx}. Html structure not aligned")
    except AttributeError:
        logging.error("Unable to retrieve urls for letters. Html structure not aligned")
    
    logging.info(f"Got letters {letters}")
    
    return letters, urls
            
def retrieve_artists(letter, letter_url, driver):
    
    logging.info(f"\nRetrieving artists for letter {letter}")
    
    driver.get(letter_url)
    html = driver.page_source
    logging.info("Html source loaded")
    soup = BeautifulSoup(html, "lxml")
    
    artists = dict()
    
    # top six artists first
    logging.info("Retrieving top artists")
    try:
        top_artists = soup.find("div", class_="module top-artists clearfix")\
                            .find_all("div", class_=['artist grid_2 alpha', 'artist grid_2 ', "artist grid_2 omega"])
        for idx, artist in enumerate(top_artists):
            try:
                box = artist.find("a", class_="image")
                artist_url = box.get("href")
                artist_name = box.find("span", class_="name").get_text()
                artist_genre = ""
                substitute = re.compile("\s*(L|l)yrics.*")
                artist_name = re.sub(substitute, "", artist_name).replace("\n", "").replace("\t", "")
                artists[artist_name] = artist_url, artist_genre
                logging.info(f"Got {artist_name}")
            except AttributeError:
                logging.warning(f"Unable to retrieve top artist number {idx}. Html structure not aligned")        
    except AttributeError:
        logging.warning(f"Unable to retrieve top artists. Html structure not aligned")
    
    # other artists
    logging.info("Retrieving other artists")
    try:
        other_artists = soup.find("table", class_="songs-table").find("tbody").find_all("tr")
        for idx, artist in enumerate(other_artists):
            try:
                box = artist.find("a")
                artist_url = box.get("href")
                artist_name = box.get_text()
                artist_genre = artist.find_all("td")[1].get_text().replace("\n", "").replace("\t", "")
                if artist_genre == "":
                    artist_genre = np.nan
                substitute = re.compile("\s*(L|l)yrics.*")
                artist_name = re.sub(substitute, "", artist_name).replace("\n", "").replace("\t", "")
                artists[artist_name] = artist_url, artist_genre
                logging.info(f"Got {artist_name}")
            except AttributeError:
                logging.warning(f"Unable to retrieve other artist number {idx}. Html structure not aligned")        
    except AttributeError:
        logging.warning(f"Unable to retrieve other artists. Html structure not aligned")
    
    logging.info(f"Retrieved {len(artists.keys())} artists for letter {letter}")
    
    return artists
        
        
def retrieve_songs(artist, artist_url, driver, per_artist_limit):

    logging.info(f"\nRetrieving songs for {artist}")
    
    driver.get(artist_url)
    html = driver.page_source
    logging.info("Html source loaded")
    soup = BeautifulSoup(html, "lxml")
    
    try:
        titles_soup = soup.find("div", id="popular").find("div", class_="content").find("tbody").find_all("tr")
    except AttributeError:
        logging.warning(f"Unable to retrieve songs for {artist}. Html structure not aligned")
    
    titles = []
    if per_artist_limit is None:
        per_artist_limit = len(titles_soup)
    for idx, song in enumerate(titles_soup[:per_artist_limit]):
        try:
            substitute = re.compile("\s*(L|l)yrics.*")
            title = song.find("a", class_=["title hasvidtable", "title "]).get_text()
            title = re.sub(substitute, "", title).replace("\n", "").replace("\t", "")
            titles.append(title)
            logging.info(f"Got {title}")
        except AttributeError:
            logging.warning(f"Unable to retrieve song number {idx}. Html structure not aligned")
    
    logging.info(f"Retrieved {len(titles)} songs for {artist}")
    
    return titles

# %% [markdown]
# ### Use Genius API to get lyrics

# %%
def retrieve_lyrics(df_songs, genius_api, output_filename, avoid_artists=[]):
    
    dataset = df_songs
    artists = [arts for arts in dataset.artist.unique()[::-1] if arts not in avoid_artists]
    logging.info(f"Starting after {avoid_artists[-1]}")
    counter = 0
    counter_overall = 0
    
    for artist in artists:
        logging.info(f"\nRetrieving lyrics for {artist}")
        songs = dataset.loc[dataset.artist == artist, "song"].to_list()
        album = []
        lyrics = []
        release_date = []
        for idx, song_title in enumerate(songs):
            
            try:
                song = genius_api.search_song(song_title, artist=artist)
            except Exception as e:           
                try:
                    logging.warning(f"{song_title}, {artist} not found: {e.message} {e.args}")
                except AttributeError:
                    logging.warning(f"{song_title}, {artist} {song_title}, {artist} not found: {e}")
                
                dataset = dataset.drop(
                                index=dataset.loc[(dataset.artist == artist) & (dataset.song == song_title)].index
                                ).reset_index(drop=True)
                
                counter_overall += 1
                print(f"\rLyrics retrieved: {counter} Total songs: {counter_overall}", end='\r')
                sys.stdout.flush()
                continue
            
            try:
                text = song.lyrics
                substitute = re.compile("\[.+\]")
                text = re.sub(substitute, "", text).replace("\n", " ").replace("\t", " ")
                
                try:
                    language = TextBlob(text).detect_language()
                except Exception as e:
                    try:
                        logging.warning(f"Problem detecting language for {song_title}, {artist}: {e.message} {e.args}")
                    except AttributeError:
                        logging.warning(f"Problem detecting language for {song_title}, {artist}: {e}")
                    language = "en"
                if language != "en":
                    dataset = dataset.drop(
                                index=dataset.loc[(dataset.artist == artist) & (dataset.song == song_title)].index
                                ).reset_index(drop=True)
                    logging.warning(f"Excluded {song_title}, {artist}. Lyrics language: {language}")
                    counter_overall += 1
                    print(f"\rLyrics retrieved: {counter} Total songs: {counter_overall}", end='\r')
                    sys.stdout.flush()
                    continue
                else:
                    if len(text.split()) < 10000:
                        lyrics.append(text)
                    # avoid outliers --> surely not song lyrics
                    else:
                        dataset = dataset.drop(
                                index=dataset.loc[(dataset.artist == artist) & (dataset.song == song_title)].index
                                ).reset_index(drop=True)
                        logging.warning(f"Excluded {song_title}, {artist}. Lyrics longer than 10000 words")
                        counter_overall += 1
                        print(f"\rLyrics retrieved: {counter} Total songs: {counter_overall}", end='\r')
                        sys.stdout.flush()
                        continue
                        
            except AttributeError:
                logging.warning(f"No lyrics for {song_title}. Dropping")
                dataset = dataset.drop(
                                index=dataset.loc[(dataset.artist == artist) & (dataset.song == song_title)].index
                                ).reset_index(drop=True)
                counter_overall += 1
                print(f"\rLyrics retrieved: {counter} Total songs: {counter_overall}", end='\r')
                sys.stdout.flush()
                continue
            
            try:
                album.append(song.album.replace("\n", "").replace("\t", ""))
            except AttributeError:
                album.append(np.nan)
            
            try:
                release_date.append(song.year.replace("\n", "").replace("\t", ""))
            except AttributeError:
                release_date.append(np.nan)
            
            logging.info(f"Got data for {song_title}")
            counter += 1
            counter_overall += 1
            print(f"\rLyrics retrieved: {counter} Total songs: {counter_overall}", end='\r')
            sys.stdout.flush()
        
        logging.info(f"Retrieved lyrics for {artist}")
        logging.info(f"Artist Dataset shape: {dataset.loc[dataset.artist == artist, :].shape}, Albums: {len(album)}, Lyrics: {len(lyrics)}, Release Date: {len(release_date)}")
        
        dataset.loc[dataset.artist == artist, "album"] = album
        dataset.loc[dataset.artist == artist, "lyrics"] = lyrics
        dataset.loc[dataset.artist == artist, "release_date"] = release_date        
        
        logging.info(f"Writing {artist} to csv")
        logging.info(f"Global Dataset shape: {dataset.shape}")
        dataset.to_csv(f"/Users/lucamasserano/Desktop/BOCCONI/nlp/final_project/lyrics_project/{output_filename}.csv", index=False)
    
    return dataset

# %% [markdown]
# ### Final dataframe

# %%
df_initial = pd.DataFrame({"artist":[], "song":[], "album":[], "release_date":[], "genre":[], "lyrics":[]})
df_initial.head()
# Out:
# Empty DataFrame
# Columns: [artist, song, album, release_date, genre, lyrics]
# Index: []

# %% [markdown]
# ### Get songs

# %%
driver = driver = webdriver.Firefox(executable_path="/Users/lucamasserano/Desktop/BOCCONI/Business Analytics/geckodriver")
songs = metrolyrics_retriever(df_initial, driver)
songs.shape

# %%
songs = pd.read_csv("/Users/lucamasserano/Desktop/BOCCONI/nlp/final_project/lyrics_project/songs.csv")

# %%
songs.shape
# Out:
# (62470, 6)

# %% [markdown]
# ### Get lyrics

# %%
api = lyricsgenius.Genius("BywKEeMHzO4cTLacaE-fUln9w7quBz13Hj6c10_Pm172KFstTUt_I3nJGFIPTxo9", sleep_time=0.01, verbose=False)

# %%
arts_1 = pd.read_csv("/Users/lucamasserano/Desktop/BOCCONI/nlp/final_project/lyrics_project/first_part.csv").artist.unique()
arts_1
# Out:
# array(['6ix9ine', '50 Cent', '2Pac', '30 Seconds to Mars', '6cyclemind',
#        '5 Seconds Of Summer', '4 Non Blondes', '69 Boyz', '3 Doors Down',
#        "3 Lions '98", '52 Savage', '21 Savage', '911', '311', '88RISING',
#        '2 Chainz', '38 Special', '10,000 Maniacs', '10 Years',
#        '2 Live Crew', '98 Degrees', '10cc', '3OH!3', '112', '1000Mods',
#        '6LACK', '1140 Mississippi', '11th Hour', '2 Unlimited', '4 Him',
#        '2Face Idibia', '20 Fingers', '3 Piece', '30H3', '2NE1',
#        '1st Lady', '702', '7horse', '36 Crazyfists', '047', '3T', '3LAU',
#        'Atif Aslam', 'ABBA', 'Adele', 'A. R. Rahman', 'Annie',
#        'Armaan Malik', 'Alicia Keys', 'Ariana Grande', 'Aladdin',
#        'Amrit Maan', 'Avril Lavigne', 'Amy Winehouse', 'Aizat Amdan',
#        'ARASH', 'Alan Walker', 'Akon', 'Andrea Bocelli', 'Arctic Monkeys',
#        'ASAP Rocky', 'Aventura', 'Ammy Virk', 'Avicii',
#        'Anthony Brown & Group Therapy', 'Adhitia Sofyan', 'Aerosmith',
#        'Alan Jackson', 'Anna Kendrick', 'Amanda Seyfried',
#        'Andy Williams', 'Andrew Lloyd Webber', 'Andrew E', 'America',
#        'Air Supply', 'Aretha Franklin', 'Ashley Tisdale', 'Ariel Rivera',
#        'Alanis Morissette', 'Abdullah İnal', 'AC/DC', 'The Animals',
#        'A-Ha', 'Brett Young', 'The Beatles', 'Bruno Mars', 'Ben&Ben',
#        'Brian McKnight', 'Bob Marley', 'Beyonce Knowles', 'Bob Dylan',
#        'Beyoncé', 'Bonnie Tyler', 'Baz Luhrmann', 'BIGBANG', 'Bamboo',
#        'Billy Joel', 'Bob Seger', 'Bee Gees', 'BTS (방탄소년단)',
#        'Britney Spears', 'Bryan Adams', 'Bon Jovi', 'Black Eyed Peas',
#        'Backstreet Boys', 'The Carters', 'Ben E. King', 'Bethel Music',
#        'Barbra Streisand', 'Brad Paisley', 'Blink-182', 'Bill Withers',
#        'BLACKPINK', 'Boyz II Men', 'Bring It On', 'Billie Holiday',
#        'Bruce Springsteen', 'Blake Shelton', 'B.B. King', 'Beck',
#        'Bing Crosby', 'Byron Cage', 'Billie Eilish', 'Bette Midler',
#        'Band', 'Coldplay', 'Children Songs', 'Céline Dion',
#        'The Carpenters', 'CupcakKe', 'Christina Perri',
#        'Christmas Carols', 'Cardi B', 'Chris Brown', 'Christmas Song',
#        'Chris Tomlin', 'Creedence Clearwater Revival',
#        'Chicago The Musical', 'Charlie Puth', 'Caleb Santos',
#        'The Cranberries', 'Christina Aguilera', 'The Chainsmokers',
#        'Cast of Camp Rock', 'Original Cast of "Cats"', 'Cher',
#        'Carrie Underwood', 'Camila Cabello', 'The Cure', 'Clean Bandit',
#        'Colbie Caillat', 'Carly Simon', 'Cat Stevens', 'Cheap Trick',
#        'Cyndi Lauper', 'Childish Gambino', 'Charles Jenkins',
#        'A Chorus Line', 'Chance The Rapper', 'Cinderella',
#        'Calvin Harris', 'Coolio', 'Cedarmont Kids', 'Cabaret', 'Ciara',
#        'Crosby Stills Nash', 'Casting Crowns', 'Drake', 'Disney',
#        'Demi Lovato', 'DJ Khaled', 'Dolly Parton', 'David Bowie',
#        'Dean Martin', 'Dave Matthews Band', 'Dr. Tumi', 'December Avenue',
#        'Don Moen', 'David Guetta', 'Dylan Jacob', 'Diana Ross',
#        'Depeche Mode', 'Donnie McClurkin', "Destiny's Child",
#        'Daddy Yankee', 'Dubliners', 'Daryl Ong', 'Drew K.',
#        'Dire Straits', 'Dierks Bentley', 'David Allan Coe',
#        'Dora The Explorer', 'Dreamgirls', 'Dixie Chicks', 'Daughtry',
#        'Dionne Warwick', 'Doris Day', 'Dean Lewis', 'Don McLean',
#        'Don Williams', 'DMX', 'Deep Purple', 'Damien Rice', 'Dua Lipa',
#        'Don Henley', 'DJ Snake', 'Don Omar', 'Donovan', 'Ed Sheeran',
#        'Eminem', 'Elton John', 'Ella Fitzgerald', 'Elvis Presley',
#        'Eraserheads', 'Edith Piaf', 'Enrique Iglesias', 'Eagles',
#        'Electric Light Orchestra', 'Eric Clapton', 'Etta James',
#        'Earth Wind & Fire', 'Ellie Goulding', 'Evanescence', 'E.l.o.',
#        'Emmylou Harris', 'The Everly Brothers', 'Eric Church', 'Estelle',
#        'Erbil Erdan', 'Eddy Arnold', 'Eddie Vedder', 'Elevation Worship',
#        'Evvie McKinney', 'Endah N Rhesa', 'Eurythmics', 'Enya',
#        'Elvis Costello', 'Emerson, Lake & Palmer', 'Epica', 'Ella Mai',
#        'Erasure', 'Elle King', 'Edwin McCain', 'Extreme', 'Emeli Sandé',
#        'Everything But The Girl'], dtype=object)

# %%
arts_2 = pd.read_csv("/Users/lucamasserano/Desktop/BOCCONI/nlp/final_project/lyrics_project/second_part.csv")
arts_2.artist.unique()

# %%
arts_retrieved = np.concatenate((arts_1, arts_2.loc[arts_2.lyrics.notnull(), :].artist.unique())) 
arts_retrieved
# Out:
# array(['6ix9ine', '50 Cent', '2Pac', '30 Seconds to Mars', '6cyclemind',
#        '5 Seconds Of Summer', '4 Non Blondes', '69 Boyz', '3 Doors Down',
#        "3 Lions '98", '52 Savage', '21 Savage', '911', '311', '88RISING',
#        '2 Chainz', '38 Special', '10,000 Maniacs', '10 Years',
#        '2 Live Crew', '98 Degrees', '10cc', '3OH!3', '112', '1000Mods',
#        '6LACK', '1140 Mississippi', '11th Hour', '2 Unlimited', '4 Him',
#        '2Face Idibia', '20 Fingers', '3 Piece', '30H3', '2NE1',
#        '1st Lady', '702', '7horse', '36 Crazyfists', '047', '3T', '3LAU',
#        'Atif Aslam', 'ABBA', 'Adele', 'A. R. Rahman', 'Annie',
#        'Armaan Malik', 'Alicia Keys', 'Ariana Grande', 'Aladdin',
#        'Amrit Maan', 'Avril Lavigne', 'Amy Winehouse', 'Aizat Amdan',
#        'ARASH', 'Alan Walker', 'Akon', 'Andrea Bocelli', 'Arctic Monkeys',
#        'ASAP Rocky', 'Aventura', 'Ammy Virk', 'Avicii',
#        'Anthony Brown & Group Therapy', 'Adhitia Sofyan', 'Aerosmith',
#        'Alan Jackson', 'Anna Kendrick', 'Amanda Seyfried',
#        'Andy Williams', 'Andrew Lloyd Webber', 'Andrew E', 'America',
#        'Air Supply', 'Aretha Franklin', 'Ashley Tisdale', 'Ariel Rivera',
#        'Alanis Morissette', 'Abdullah İnal', 'AC/DC', 'The Animals',
#        'A-Ha', 'Brett Young', 'The Beatles', 'Bruno Mars', 'Ben&Ben',
#        'Brian McKnight', 'Bob Marley', 'Beyonce Knowles', 'Bob Dylan',
#        'Beyoncé', 'Bonnie Tyler', 'Baz Luhrmann', 'BIGBANG', 'Bamboo',
#        'Billy Joel', 'Bob Seger', 'Bee Gees', 'BTS (방탄소년단)',
#        'Britney Spears', 'Bryan Adams', 'Bon Jovi', 'Black Eyed Peas',
#        'Backstreet Boys', 'The Carters', 'Ben E. King', 'Bethel Music',
#        'Barbra Streisand', 'Brad Paisley', 'Blink-182', 'Bill Withers',
#        'BLACKPINK', 'Boyz II Men', 'Bring It On', 'Billie Holiday',
#        'Bruce Springsteen', 'Blake Shelton', 'B.B. King', 'Beck',
#        'Bing Crosby', 'Byron Cage', 'Billie Eilish', 'Bette Midler',
#        'Band', 'Coldplay', 'Children Songs', 'Céline Dion',
#        'The Carpenters', 'CupcakKe', 'Christina Perri',
#        'Christmas Carols', 'Cardi B', 'Chris Brown', 'Christmas Song',
#        'Chris Tomlin', 'Creedence Clearwater Revival',
#        'Chicago The Musical', 'Charlie Puth', 'Caleb Santos',
#        'The Cranberries', 'Christina Aguilera', 'The Chainsmokers',
#        'Cast of Camp Rock', 'Original Cast of "Cats"', 'Cher',
#        'Carrie Underwood', 'Camila Cabello', 'The Cure', 'Clean Bandit',
#        'Colbie Caillat', 'Carly Simon', 'Cat Stevens', 'Cheap Trick',
#        'Cyndi Lauper', 'Childish Gambino', 'Charles Jenkins',
#        'A Chorus Line', 'Chance The Rapper', 'Cinderella',
#        'Calvin Harris', 'Coolio', 'Cedarmont Kids', 'Cabaret', 'Ciara',
#        'Crosby Stills Nash', 'Casting Crowns', 'Drake', 'Disney',
#        'Demi Lovato', 'DJ Khaled', 'Dolly Parton', 'David Bowie',
#        'Dean Martin', 'Dave Matthews Band', 'Dr. Tumi', 'December Avenue',
#        'Don Moen', 'David Guetta', 'Dylan Jacob', 'Diana Ross',
#        'Depeche Mode', 'Donnie McClurkin', "Destiny's Child",
#        'Daddy Yankee', 'Dubliners', 'Daryl Ong', 'Drew K.',
#        'Dire Straits', 'Dierks Bentley', 'David Allan Coe',
#        'Dora The Explorer', 'Dreamgirls', 'Dixie Chicks', 'Daughtry',
#        'Dionne Warwick', 'Doris Day', 'Dean Lewis', 'Don McLean',
#        'Don Williams', 'DMX', 'Deep Purple', 'Damien Rice', 'Dua Lipa',
#        'Don Henley', 'DJ Snake', 'Don Omar', 'Donovan', 'Ed Sheeran',
#        'Eminem', 'Elton John', 'Ella Fitzgerald', 'Elvis Presley',
#        'Eraserheads', 'Edith Piaf', 'Enrique Iglesias', 'Eagles',
#        'Electric Light Orchestra', 'Eric Clapton', 'Etta James',
#        'Earth Wind & Fire', 'Ellie Goulding', 'Evanescence', 'E.l.o.',
#        'Emmylou Harris', 'The Everly Brothers', 'Eric Church', 'Estelle',
#        'Erbil Erdan', 'Eddy Arnold', 'Eddie Vedder', 'Elevation Worship',
#        'Evvie McKinney', 'Endah N Rhesa', 'Eurythmics', 'Enya',
#        'Elvis Costello', 'Emerson, Lake & Palmer', 'Epica', 'Ella Mai',
#        'Erasure', 'Elle King', 'Edwin McCain', 'Extreme', 'Emeli Sandé',
#        'Everything But The Girl', 'Eros Ramazzotti', 'Edguy',
#        'Eva Cassidy', 'Empire Of The Sun', 'Frank Sinatra',
#        'Fleetwood Mac', 'Fiona Apple', 'Foo Fighters', 'Fall Out Boy',
#        'Frank Ocean', 'Freestyle', 'Florence + The Machine',
#        'Fritz Hagen', 'Frank Zappa', 'Fred Hammond', 'Freddie Aguilar',
#        'Florida Georgia Line', 'Foster The People', 'Fergie', 'Flo Rida',
#        'Fun.', 'Future', 'Flatt and Scruggs', 'Fifth Harmony',
#        'Fats Domino', 'Foreigner', 'Flight of the Conchords', 'The Fray',
#        'Faith Hill', 'Five Finger Death Punch', 'Fabolous', 'The Fugees',
#        'Free Chapel', 'Fever Ray', 'Father Ray Kelly', 'The Four Seasons',
#        'Fenix', 'Fiona Fung', 'Five For Fighting', 'Four Tops',
#        'Fairport Convention', 'Frankie Laine', 'Franz Ferdinand',
#        'Fatboy Slim', 'Frazey Ford', 'Faron Young', 'Fela Kuti',
#        'Guru Randhawa', 'Grease', 'Garth Brooks', 'Green Day',
#        'Gary Valenciano', 'Grateful Dead', 'Goo Goo Dolls',
#        'Gaither Vocal Band', 'George Strait', 'George Jones', 'Gorillaz',
#        'Soweto Gospel Choir', 'Garry Sandhu', 'George Michael',
#        'Gloria Gaynor', 'Gajendra Verma', "Guns 'N Roses", 'George Ezra',
#        'Gwen Stefani', 'Gary Jules', 'Gipsy Kings'], dtype=object)

# %%
lyrics = retrieve_lyrics(songs, api, output_filename="reversed", avoid_artists=arts_retrieved)
lyrics.shape
# Out:
# Timeout raised and caught:l songs: 549
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 4855
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 4958
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 5142
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 5183
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 5226
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 8326
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 8612
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 9012
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 11226
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 11613
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 11890
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:tal songs: 15585
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:tal songs: 15920
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:tal songs: 15952
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:tal songs: 16511
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Lyrics retrieved: 13282 Total songs: 17638
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-15895cee19ea> in <module>
# ----> 1 lyrics = retrieve_lyrics(songs, api, output_filename="reversed", avoid_artists=arts_retrieved)
#       2 lyrics.shape
#
# <ipython-input-22-1923833e7ac8> in retrieve_lyrics(df_songs, genius_api, output_filename, avoid_artists)
#      97         logging.info(f"Artist Dataset shape: {dataset.loc[dataset.artist == artist, :].shape}, Albums: {len(album)}, Lyrics: {len(lyrics)}, Release Date: {len(release_date)}")
#      98
# ---> 99         dataset.loc[dataset.artist == artist, "album"] = album
#     100         dataset.loc[dataset.artist == artist, "lyrics"] = lyrics
#     101         dataset.loc[dataset.artist == artist, "release_date"] = release_date
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     654             self.obj._consolidate_inplace()
#     655             self.obj._data = self.obj._data.setitem(indexer=indexer,
# --> 656                                                     value=value)
#     657             self.obj._maybe_update_cacher(clear=True)
#     658
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in setitem(self, **kwargs)
#     508
#     509     def setitem(self, **kwargs):
# --> 510         return self.apply('setitem', **kwargs)
#     511
#     512     def putmask(self, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value)
#     918         # set
#     919         else:
# --> 920             values[indexer] = value
#     921
#     922         # coerce and try to infer the dtypes of the result
#
# ValueError: cannot copy sequence with size 147 to array axis with dimension 146

# %% [markdown]
# ### Get lyrics if `retrieve_lyrics()` stopped at some point. Restart after last artist retrieved

# %%
checkpoint = pd.read_csv("/Users/lucamasserano/Desktop/BOCCONI/nlp/final_project/lyrics_project/reversed.csv")
artists_checkpoint = checkpoint.loc[checkpoint.lyrics.notnull(), "artist"].unique()
artists_checkpoint
# Out:
# array(['Red Hot Chili Peppers', 'Radiohead', 'Rammstein', 'Rod Stewart',
#        'Ray Stevens', 'Race', 'Rascal Flatts', 'Ray Charles',
#        'Regine Velasquez', 'Rocky Horror Picture Show', 'Roy Orbison',
#        'R. Kelly', 'Russ', 'Rodney Carrington', 'The Righteous Brothers',
#        'Robbie Williams', 'Roan Ash', 'Reba McEntire',
#        'Ricky Dillard & New G', 'Rush', 'Roger Miller', 'Reed Foehl',
#        'Randy Newman', 'Rupert Holmes', 'Romeo Santos', 'Roberta Flack',
#        'The Ramones', 'REM', 'Ricky Martin', 'Roxette', 'Raisa',
#        'Ray LaMontagne', 'Robyn', 'Ram Jam', 'Sabyan Gambus',
#        'SpongeBob SquarePants', 'Sound Of Music', 'Sugar free',
#        'Sam Smith', 'Sia', 'Silent Sanctuary', 'Shawn Mendes',
#        'Selena Gomez', 'South Park', 'Shakira', 'Sarah Geronimo',
#        'Scooby Doo Theme Songs', 'Simon And Garfunkel', 'Spongecola',
#        'Sesame Street', 'Stephen Bishop', 'Shankar Mahadevan',
#        'Steven Universe', 'Songs For Children', 'Soundtrack',
#        'Shania Twain', 'Snow Patrol', 'Samsons', 'Sam Concepcion',
#        'Stevie Wonder', 'Sharry Maan', 'Soulja Boy',
#        'The Smashing Pumpkins', 'Santana', 'Selena', 'Snoop Dogg', 'Sade',
#        'System Of A Down', 'Simpsons', 'Taylor Swift', 'Traditional',
#        'Twenty One Pilots', 'Train', 'The Weeknd', 'Toto', 'Tim McGraw',
#        'Travis Greene', 'Travis Scott', 'Tina Turner', 'T.I.',
#        'Tasha Cobbs', 'Toni Gonzaga', 'T-Pain', 'Ted Gärdestad',
#        'Tangerine Kitty', 'The 1975', 'Tracy Chapman', 'Typecast', 'Tyga',
#        'Tv Theme', 'Tony Bennett', 'TLC', 'The Smiths', 'Usher', 'U2',
#        'Unknown', 'Urban Dub', 'Ub40', 'Usa For Africa', 'Uncle Kracker',
#        'Uriah Heep', 'Underworld', 'Ultravox', 'Ufo', 'US Marine Corps',
#        'U. D. O.', 'Utopia', 'Utada Hikaru', 'The Used', 'Unwound', 'UGK',
#        "Umphrey's McGee", 'Uncle Acid and the Deadbeats', 'UK Subs',
#        'Us the Duo', 'Uncle Tupelo', 'The Underdog Project', 'Unique',
#        'The Undertones', 'Undertaker', 'Uverworld', 'Ultra Nate',
#        'Unbekannt', 'UnSun', 'Unkle', 'Vanessa Hudgens', 'Van Morrison',
#        'VeggieTales', 'Victorious Cast', 'Velasquez Regine', 'Van Halen',
#        'Vitas', 'Vera Lynn', 'Vance Joy', 'Vidya Vox', 'Vince Gill',
#        'Vybz Kartel', 'Vaya Con Dios', 'Victorious', 'The Vamps',
#        'Vampire Weekend', 'Victoria Justice', 'Vicki Yohe',
#        'Village People', 'Vengaboys', 'Vashawn Mitchell', 'The Verve',
#        'Vanessa Williams', 'Volbeat', 'Vicente Fernandez', 'Vanilla Ice',
#        'Vanessa Carlton', 'Vishal Dadlani', 'Venom', 'Villagers',
#        'Valli Frankie', 'The Vandals', 'V6', 'Van Der Graaf Generator',
#        'Violent Femmes', 'The Velvet Underground', 'Westlife', 'We Three',
#        'WICKED CREW', 'Willie Nelson', 'Wizard Of Oz', 'Whitney Houston',
#        'Chorus of Winnie The Pooh', 'Westside Story', 'WWE',
#        '"Weird Al" Yankovic', 'Will Smith', 'Wiz Khalifa',
#        'William Mcdowell', 'william murphy', 'Waylon Jennings', 'Weezer',
#        'Wolfgang', 'Widespread Panic', 'The Who', 'Walter Hawkins',
#        'The White Stripes', 'will.i.am', 'Wham!', 'W.A.S.P.',
#        'Wanda Jackson', 'The White Buffalo', 'Warren Zevon',
#        'We the Kings', 'Wale', 'Wrestling', 'Ween', 'Whitesnake',
#        "Why Don't We", 'Woody Guthrie', 'The Wolfe Tones',
#        'Within Temptation', 'Whiskey Myers', 'Whispers', 'Wu-Tang Clan',
#        'Wander Over Yonder', 'Walk The Moon', 'XXXTENTACION',
#        'Xavier Rudd', 'The Xx', 'Xandria', 'Xscape', 'XYLØ', 'Xzibit',
#        'X Factor (UK)', 'X-Treme', 'X-Perience', 'Xiu Xiu',
#        'Ximena Sarinana', 'X-Ray Spex', 'Xavier Omar', 'XXL', 'XOX',
#        'X-Pose', 'Xymox', 'X Factor (US)', 'xikidi', 'Xuitcasecity',
#        'Xentrix', 'Xiao Yu', 'Xana Toc Toc', 'XV', 'Xo Icy',
#        'Xenia Ghali', 'Xasthur', 'Xenia Rubinos', 'Xmal Deutschland',
#        'x factor finalists', 'X-Ecutioners', 'XY&O', 'Yeng Constantino',
#        'Yuvan Shankar Raja', 'Yo Yo Honey Singh', 'Yung Raja',
#        'YoungBoy Never Broke Again', 'YG', 'Yuna', 'Yolanda Adams', 'Yes',
#        'Yngwie Malmsteen', 'Young Thug', 'Young Jeezy', 'Yusuf Islam',
#        'Ying Yang Twins', 'Yves Larock', 'Yo Gotti', 'Years & Years',
#        'Ylvis', 'The Yogscast', 'Yelawolf', 'yeah yeah yeahs',
#        'Yellow Claw', 'Yanni', 'Yura Yunita', 'You+Me', 'Yiruma',
#        'Young The Giant', 'Yello', 'Young Money', 'You Me At Six',
#        'Yoko Ono', 'Young Nudy', 'Yardbirds', 'Yaz', 'Young Buck', 'You',
#        'Zayn Malik', 'Zack Knight', 'Zac Efron', 'Zac Brown Band',
#        'Zhavia Ward', 'ZZ Top', 'Zonke Dikana', 'Zedd', 'Zee Avi',
#        'The Zombies', 'Zoe', 'Zara Larsson', 'Ziggy Marley',
#        'Zach Williams', 'ZAYN', 'Ziv Zaifman', 'Ziggy Alberts',
#        'Zach Callison', 'Zucchero', 'Zakk Wylde', 'Zendaya',
#        'Zacarias Ferreira', 'Zebra', 'Z-Ro', 'Zumba Fitness',
#        'Zooey Deschanel', 'Zhu', 'zeds dead', 'Zanda Zakuza', 'Zac Brown',
#        'Zero 7', 'Zager and Evans', 'Zonke', 'zain bhikha', 'Z-FLO',
#        'ZZ Ward', 'Zhane'], dtype=object)

# %%
lyrics = retrieve_lyrics(checkpoint, api, avoid_artists=artists_checkpoint)
lyrics.shape
# Out:
# Timeout raised and caught: songs: 55
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Lyrics retrieved: 607 Total songs: 659
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-a3b31c8ab297> in <module>
# ----> 1 lyrics = retrieve_lyrics(checkpoint, api, avoid_artists=artists_checkpoint)
#       2 lyrics.shape
#
# <ipython-input-17-ca8ab5b1122c> in retrieve_lyrics(df_songs, genius_api, avoid_artists)
#      16
#      17             try:
# ---> 18                 song = genius_api.search_song(song_title, artist=artist)
#      19             except Exception as e:
#      20                 try:
#
# ~/anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in search_song(self, title, artist, get_full_info)
#     266         if get_full_info:
#     267             song_info.update(self.get_song(result['id'])['song'])
# --> 268         lyrics = self._scrape_song_lyrics_from_url(song_info['url'])
#     269
#     270         # Skip results when URL is a 404 or lyrics are missing
#
# ~/anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in _scrape_song_lyrics_from_url(self, url)
#     161         :param url: URL for the web page to scrape lyrics from
#     162         """
# --> 163         page = requests.get(url)
#     164         if page.status_code == 404:
#     165             return None
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %% [markdown]
# ### As dataset gets bigger the retrieval slows down --> Partition the dataset and then concatenate

# %%
retrieved = pd.read_csv("/Users/lucamasserano/Desktop/BOCCONI/nlp/final_project/lyrics_project/lyrics.csv")

# %%
artists_retrieved = retrieved.loc[retrieved.lyrics.notnull(), "artist"].unique()
artists_retrieved
# Out:
# array(['6ix9ine', '50 Cent', '2Pac', '30 Seconds to Mars', '6cyclemind',
#        '5 Seconds Of Summer', '4 Non Blondes', '69 Boyz', '3 Doors Down',
#        "3 Lions '98", '52 Savage', '21 Savage', '911', '311', '88RISING',
#        '2 Chainz', '38 Special', '10,000 Maniacs', '10 Years',
#        '2 Live Crew', '98 Degrees', '10cc', '3OH!3', '112', '1000Mods',
#        '6LACK', '1140 Mississippi', '11th Hour', '2 Unlimited', '4 Him',
#        '2Face Idibia', '20 Fingers', '3 Piece', '30H3', '2NE1',
#        '1st Lady', '702', '7horse', '36 Crazyfists', '047', '3T', '3LAU',
#        'Atif Aslam', 'ABBA', 'Adele', 'A. R. Rahman', 'Annie',
#        'Armaan Malik', 'Alicia Keys', 'Ariana Grande', 'Aladdin',
#        'Amrit Maan', 'Avril Lavigne', 'Amy Winehouse', 'Aizat Amdan',
#        'ARASH', 'Alan Walker', 'Akon', 'Andrea Bocelli', 'Arctic Monkeys',
#        'ASAP Rocky', 'Aventura', 'Ammy Virk', 'Avicii',
#        'Anthony Brown & Group Therapy', 'Adhitia Sofyan', 'Aerosmith',
#        'Alan Jackson', 'Anna Kendrick', 'Amanda Seyfried',
#        'Andy Williams', 'Andrew Lloyd Webber', 'Andrew E', 'America',
#        'Air Supply', 'Aretha Franklin', 'Ashley Tisdale', 'Ariel Rivera',
#        'Alanis Morissette', 'Abdullah İnal', 'AC/DC', 'The Animals',
#        'A-Ha', 'Brett Young', 'The Beatles', 'Bruno Mars', 'Ben&Ben',
#        'Brian McKnight', 'Bob Marley', 'Beyonce Knowles', 'Bob Dylan',
#        'Beyoncé', 'Bonnie Tyler', 'Baz Luhrmann', 'BIGBANG', 'Bamboo',
#        'Billy Joel', 'Bob Seger', 'Bee Gees', 'BTS (방탄소년단)',
#        'Britney Spears', 'Bryan Adams', 'Bon Jovi', 'Black Eyed Peas',
#        'Backstreet Boys', 'The Carters', 'Ben E. King', 'Bethel Music',
#        'Barbra Streisand', 'Brad Paisley', 'Blink-182', 'Bill Withers',
#        'BLACKPINK', 'Boyz II Men', 'Bring It On', 'Billie Holiday',
#        'Bruce Springsteen', 'Blake Shelton', 'B.B. King', 'Beck',
#        'Bing Crosby', 'Byron Cage', 'Billie Eilish', 'Bette Midler',
#        'Band', 'Coldplay', 'Children Songs', 'Céline Dion',
#        'The Carpenters', 'CupcakKe', 'Christina Perri',
#        'Christmas Carols', 'Cardi B', 'Chris Brown', 'Christmas Song',
#        'Chris Tomlin', 'Creedence Clearwater Revival',
#        'Chicago The Musical', 'Charlie Puth', 'Caleb Santos',
#        'The Cranberries', 'Christina Aguilera', 'The Chainsmokers',
#        'Cast of Camp Rock', 'Original Cast of "Cats"', 'Cher',
#        'Carrie Underwood', 'Camila Cabello', 'The Cure', 'Clean Bandit',
#        'Colbie Caillat', 'Carly Simon', 'Cat Stevens', 'Cheap Trick',
#        'Cyndi Lauper', 'Childish Gambino', 'Charles Jenkins',
#        'A Chorus Line', 'Chance The Rapper', 'Cinderella',
#        'Calvin Harris', 'Coolio', 'Cedarmont Kids', 'Cabaret', 'Ciara',
#        'Crosby Stills Nash', 'Casting Crowns', 'Drake', 'Disney',
#        'Demi Lovato', 'DJ Khaled', 'Dolly Parton', 'David Bowie',
#        'Dean Martin', 'Dave Matthews Band', 'Dr. Tumi', 'December Avenue',
#        'Don Moen', 'David Guetta', 'Dylan Jacob', 'Diana Ross',
#        'Depeche Mode', 'Donnie McClurkin', "Destiny's Child",
#        'Daddy Yankee', 'Dubliners', 'Daryl Ong', 'Drew K.',
#        'Dire Straits', 'Dierks Bentley', 'David Allan Coe',
#        'Dora The Explorer', 'Dreamgirls', 'Dixie Chicks', 'Daughtry',
#        'Dionne Warwick', 'Doris Day', 'Dean Lewis', 'Don McLean',
#        'Don Williams', 'DMX', 'Deep Purple', 'Damien Rice', 'Dua Lipa',
#        'Don Henley', 'DJ Snake', 'Don Omar', 'Donovan', 'Ed Sheeran',
#        'Eminem', 'Elton John', 'Ella Fitzgerald', 'Elvis Presley',
#        'Eraserheads', 'Edith Piaf', 'Enrique Iglesias', 'Eagles',
#        'Electric Light Orchestra', 'Eric Clapton', 'Etta James',
#        'Earth Wind & Fire', 'Ellie Goulding', 'Evanescence', 'E.l.o.',
#        'Emmylou Harris', 'The Everly Brothers', 'Eric Church', 'Estelle',
#        'Erbil Erdan', 'Eddy Arnold', 'Eddie Vedder', 'Elevation Worship',
#        'Evvie McKinney', 'Endah N Rhesa', 'Eurythmics', 'Enya',
#        'Elvis Costello', 'Emerson, Lake & Palmer', 'Epica', 'Ella Mai',
#        'Erasure', 'Elle King', 'Edwin McCain', 'Extreme', 'Emeli Sandé',
#        'Everything But The Girl'], dtype=object)

# %%
artists_left = [a for a in retrieved.artist.unique() if a not in artists_retrieved]
artists_left
# Out:
# ['Eros Ramazzotti',
#  'Edguy',
#  'Eva Cassidy',
#  'Empire Of The Sun',
#  'Frank Sinatra',
#  'Fleetwood Mac',
#  'Farida Khanum',
#  'Fiona Apple',
#  'Foo Fighters',
#  'Fall Out Boy',
#  'Frank Ocean',
#  'Freestyle',
#  'Florence + The Machine',
#  'Fritz Hagen',
#  'Frank Zappa',
#  'Fred Hammond',
#  'Freddie Aguilar',
#  'Florida Georgia Line',
#  'Foster The People',
#  'Fergie',
#  'Flo Rida',
#  'Fun.',
#  'Future',
#  'Flatt and Scruggs',
#  'Farhan Saeed',
#  'Fuzon',
#  'Fifth Harmony',
#  'Fats Domino',
#  'Foreigner',
#  'Flight of the Conchords',
#  'The Fray',
#  'Faith Hill',
#  'Five Finger Death Punch',
#  'Fabolous',
#  'The Fugees',
#  'Free Chapel',
#  'Fever Ray',
#  'Father Ray Kelly',
#  'The Four Seasons',
#  'Fenix',
#  'Fiona Fung',
#  'Five For Fighting',
#  'Four Tops',
#  'Fairport Convention',
#  'Frankie Laine',
#  'Franz Ferdinand',
#  'Fatboy Slim',
#  'Frazey Ford',
#  'Faron Young',
#  'Fela Kuti',
#  'Guru Randhawa',
#  'Grease',
#  'Garth Brooks',
#  'Gurnam Bhullar',
#  'Green Day',
#  'Gary Valenciano',
#  'Grateful Dead',
#  'Goo Goo Dolls',
#  'Gaither Vocal Band',
#  'George Strait',
#  'George Jones',
#  'Gorillaz',
#  'Soweto Gospel Choir',
#  'Garry Sandhu',
#  'George Michael',
#  'Gloria Gaynor',
#  'Gajendra Verma',
#  "Guns 'N Roses",
#  'George Ezra',
#  'Gwen Stefani',
#  'Gary Jules',
#  'Gipsy Kings',
#  'Gucci Mane',
#  'George Harrison',
#  'Glee Cast',
#  "Gilligan's Island",
#  'G-Eazy',
#  'Genesis',
#  'Gloria Estefan',
#  'Glen Campbell',
#  'Gurj Sidhu',
#  'George Benson',
#  'GEI',
#  'Glenn Fredly',
#  'Gotye',
#  'Garou',
#  'Gnarls Barkley',
#  'guri',
#  'Geisha',
#  'Gerry And The Pacemakers',
#  'GILBERT O SULLIVAN',
#  'Grace VanderWaal',
#  'Godsmack',
#  'Gyroscope',
#  'Gregory Porter',
#  'GFriend (여자친구)',
#  'Hillsong',
#  'Hariharan',
#  'Hale',
#  'Happy Birthday',
#  'Hillsong United',
#  'Hank Williams',
#  'Hank Williams Jr.',
#  'Heart',
#  'Hannah Montana',
#  'Hiphop Tamizha',
#  'Harry Belafonte',
#  'Hael Husaini',
#  'The High Kings',
#  'Halsey',
#  'The Hit Crew',
#  'HOZIER',
#  'Hairspray Musical Orchestra',
#  'Holly Rey',
#  'Hair Cast',
#  'Hall & Oates',
#  'Hank Snow',
#  'Hillsong Worship',
#  'Haqiem Rusli',
#  'Hollies',
#  'Harry Styles',
#  'Hunter Price',
#  'Happy Days',
#  'Hannah Delisha',
#  'Hippie Sabotage',
#  'Half Girlfriend',
#  'Harrdy Sandhu',
#  'Helloween',
#  'Halestorm',
#  'Hikaru Utada (宇多田ヒカル)',
#  'Hijau Daun',
#  'Howard Shore',
#  'Hezekiah Walker',
#  'Harry Nilsson',
#  'Hov1',
#  'Haricharan',
#  'Harris Jayaraj',
#  'Hans Zimmer',
#  'Himmat Sandhu',
#  'Human League',
#  'Hillary Scott',
#  'Hailee Steinfeld',
#  'Imagine Dragons',
#  'Indila',
#  'Company - Into the Woods',
#  'Israel Houghton',
#  'Irish Rovers',
#  'IV Of Spades',
#  'The Irish Descendants',
#  'Imago',
#  'Idina Menzel',
#  'Israel & New Breed',
#  'Iron Maiden',
#  'Incubus',
#  'Iggy Azalea',
#  'Itchyworms',
#  'Imitator Tots',
#  "Israel Kamakawiwo'ole",
#  'Inna',
#  'Israel',
#  'Iris Dement',
#  'The Interrupters',
#  'Interpol',
#  'Irving Berlin',
#  'The Isley Brothers',
#  'Ilaiyaraaja',
#  'Ikimono Gakari',
#  'Insane Clown Posse',
#  'Ima Robot',
#  'Incognito',
#  'Iñigo Pascual',
#  'Inxs',
#  'Iyaz',
#  'iLe',
#  'Il Volo',
#  'Ice Cube',
#  'Indigo Girls',
#  'Ismail Izzani',
#  'Il Divo',
#  'In This Moment',
#  'Inner Circle',
#  'The Inspirations',
#  'Iyeoka',
#  'Iggy Pop',
#  'India Arie',
#  'Imogen Heap',
#  'Inder Pandori',
#  'Intocable',
#  'Jimmy Buffett',
#  'Jason Mraz',
#  'Justin Bieber',
#  'Jass Manak',
#  'Johnny Cash',
#  'Judika',
#  'Jay-Z',
#  'Judy Garland',
#  'John Denver',
#  'Journey',
#  'Jessie J',
#  'John Lennon',
#  'John Mayer',
#  'Johnny Rebel',
#  'John Legend',
#  'Justin Timberlake',
#  'J J Hairston & Youthful Praise',
#  'Jesus Culture',
#  'Jack Johnson',
#  'Jagjit Singh',
#  'Jesus Christ Superstar',
#  'James Arthur',
#  'Jamie Lynn Spears',
#  'Jennifer Lopez',
#  'Josh Groban',
#  'Janina Vela',
#  'Jeff Buckley',
#  'Joan Baez',
#  'Jim Reeves',
#  'Jay Chou (周杰倫)',
#  'Juice WRLD',
#  'Janis Joplin',
#  'J. Cole',
#  'Joyous Celebration',
#  'James Brown',
#  'Jason Aldean',
#  'Jason DeRulo',
#  'James Kilbane',
#  'John Mellencamp',
#  'Jake Paul',
#  'James Taylor',
#  'JAY-R',
#  'Janet Jackson',
#  'James Weldon Johnson',
#  'Jimmy Eat World',
#  'Johnny Horton',
#  'K. K.',
#  'KAILASH KHER',
#  'Kanye West',
#  'Kenny Chesney',
#  'Katy Perry',
#  'Kishore Kumar',
#  'Kygo',
#  'Kelly Clarkson',
#  'Keith Urban',
#  'The Killers',
#  'Kerispatih',
#  'Khalid',
#  'Kenny Rogers',
#  'Kyla',
#  'Kahraman Deniz',
#  'Kendrick Lamar',
#  'Kumar Sanu, Sadhana Sargam',
#  'Khai Bahar',
#  'Kevin Gates',
#  'Kidz Bop Kids',
#  'Kings of Leon',
#  'Kiroro',
#  'Kahitna',
#  'Kamikazee',
#  'Kirk Franklin',
#  'Kesha',
#  'Kehlani',
#  'Kristen Bell',
#  'Kari Jobe',
#  'Kenny Loggins',
#  'Kingston Trio',
#  'The King And I',
#  'Kla Project',
#  'Korn',
#  'Kris Kristofferson',
#  'Karthik',
#  'Kiss',
#  'Kinks',
#  'Kid Cudi',
#  'Kamal Raja',
#  'Kansas',
#  'Kodaline',
#  'Kate Bush',
#  'Kid Rock',
#  'Kero Kero Bonito',
#  'Kane Brown',
#  'Luis Fonsi',
#  'Lata Mangeshkar',
#  'Les Misérables - Original London Cast',
#  'Lady GaGa',
#  'Linkin Park',
#  'Lil Wayne',
#  'Lupang Hinirang',
#  'LION KING',
#  'Lana Del Rey',
#  'Little Shop Of Horrors',
#  'Louis Armstrong',
#  'Led Zeppelin',
#  'Lynyrd Skynyrd',
#  'Lionel Richie',
#  'Luis Miguel',
#  'Linda Ronstadt',
#  'Luke Bryan',
#  'Luciano Pavarotti',
#  'Lea Salonga',
#  'Little Mix',
#  'Leonard Cohen',
#  'Lynda Randle',
#  'The Lumineers',
#  'Lady Antebellum',
#  'LSD',
#  'LANY',
#  'Lifehouse',
#  'The Lonely Island',
#  'LeAnn Rimes',
#  'Lily Allen',
#  'Lisa Mishra',
#  'Little Big Town',
#  'L.V. Revanth',
#  'Loretta Lynn',
#  'Lil Eddie',
#  'Lorde',
#  'Luther Vandross',
#  'Leona Lewis',
#  'Lauryn Hill',
#  'Lil Baby',
#  'Lord Huron',
#  'Ludacris',
#  'Logic',
#  'Labrinth',
#  'Lil Uzi Vert',
#  'Lady Alma',
#  'Moonstar88',
#  'Maroon 5',
#  'Morissette Amon',
#  'Michael Jackson',
#  'Mariah Carey',
#  'Miley Cyrus',
#  'Metallica',
#  'Mankirt Aulakh',
#  'Monty Python',
#  'Marion Jola',
#  'Millind Gaba',
#  'Matilda the Musical Original Cast',
#  'Mac Miller',
#  'Mahmut Orhan',
#  'Michael W. Smith',
#  'Meryl Streep',
#  'Marshmello',
#  'Momina Mustehsan',
#  'Miss Saigon',
#  'MercyMe',
#  'Meghan Trainor',
#  'My Chemical Romance',
#  'Music Man',
#  'Madonna',
#  'Moira dela Torre',
#  'The Muppets',
#  'Marvin Gaye',
#  'Muse',
#  'Migos',
#  'Michael Bublé',
#  'My Fair Lady',
#  'Michael Carreon',
#  'Mohit Chauhan',
#  'Meat Loaf',
#  'Martin Nievera',
#  'Monsta X (몬스타엑스)',
#  'Meghna Mishra',
#  'Maher Zain',
#  'Muhammad al Hasayn',
#  'Merle Haggard',
#  'MYMP',
#  'Marty Robbins',
#  'Matisyahu',
#  'Miranda Lambert',
#  'Michael Learns To Rock',
#  'Mocca',
#  'National Anthem Orchestra',
#  'Nawab',
#  'Nicki Minaj',
#  'Nusrat Fateh Ali Khan',
#  'Neha Kakkar',
#  'Ne-Yo',
#  'Nirvana',
#  'Nat King Cole',
#  'Newsies-Original Broadway Cast',
#  'The National Anthem of Canada',
#  'Nio García',
#  'Nickelback',
#  'Ninja',
#  'Notre Dame De Paris',
#  'Neil Diamond',
#  'Nina Simone',
#  'Nena',
#  'Notorious B.I.G.',
#  'Neha Bhasin',
#  'Navv Inder',
#  'Nelly',
#  'Nashville Cast',
#  'Nancy Sinatra',
#  'Noah',
#  'Neil Young',
#  'NSync',
#  'Natalie Grant',
#  'NF',
#  'Norah Jones',
#  'Nina',
#  'Nas',
#  'Newsboys',
#  'Nine Inch Nails',
#  'Nicky Jam',
#  'Nightwish',
#  'Natalie Cole',
#  'New Order',
#  'The National',
#  'Nana Mouskouri',
#  'Natasha Bedingfield',
#  'Naif',
#  'Nik Kershaw',
#  'No Doubt',
#  'Niall Horan',
#  'The Neighbourhood',
#  'Nick Jonas',
#  'Orange And Lemons',
#  'One Direction',
#  'Oasis',
#  'Oliver',
#  'OneRepublic',
#  'Ozzy Osbourne',
#  'Owl City',
#  'O-zone',
#  'Ozuna',
#  'Outkast',
#  'Offspring',
#  'Otis Redding',
#  'Olivia Newton-John',
#  'Over October',
#  'OMD',
#  'Original Broadway Cast Recording',
#  'OPM',
#  'Oak Ridge Boys',
#  'Ouran High School Host Club',
#  'Opus',
#  'Of Monsters And Men',
#  'Opick',
#  'The Outfield',
#  'Orient Pearl',
#  'Ocean Alley',
#  'Ogie Alcasid',
#  'Old Crow Medicine Show',
#  'Ömer Faruk Bostan',
#  "The O'Jays",
#  'Olly Murs',
#  'Overkill',
#  'Olivia',
#  'ODESZA',
#  'Old Dominion',
#  'Odyssey',
#  'ONE OK ROCK',
#  'Oscar Isaac',
#  'Omarion',
#  'Omi',
#  "Old 97's",
#  'Opeth',
#  'Özlem Akgüneş',
#  'Ocean Colour Scene',
#  'O.A.R.',
#  'Outhere Brothers',
#  'Oingo Boingo',
#  'Peterpan',
#  'Parokya Ni Edgar',
#  'The Phantom of the Opera (Original London Cast)',
#  'Param Singh',
#  'Pokémon',
#  'Prince',
#  'Phineas and Ferb',
#  'P!nk',
#  'Panic! At the Disco',
#  'Pink Floyd',
#  'Pearl Jam',
#  'Pav Dharia',
#  'Pinkfong',
#  'Post Malone',
#  'Perry Como',
#  'Peter, Paul and Mary',
#  'Paramore',
#  'Pitbull',
#  'Phil Collins',
#  'Parmish Verma',
#  'Pitch Perfect',
#  'Payung Teduh',
#  'Passenger',
#  'Paul Simon',
#  'Paul McCartney',
#  'Procol Harum',
#  'Phish',
#  'Pheobe',
#  'Parov Stelar',
#  'Paula Cole',
#  'Passion',
#  'Penchal Das',
#  'The Platters',
#  'Palak Muchhal',
#  'Portugal. The Man',
#  'Pritam',
#  'Patsy Cline',
#  'The Police',
#  'Peter Gabriel',
#  "Plain White T's",
#  'Petra',
#  'The Pussycat Dolls',
#  'Patti Page',
#  'Pentatonix',
#  'Plastic Bertrand',
#  'Padi',
#  'Queen',
#  'Queen Naija',
#  'Quest',
#  'Queens of The Stone Age',
#  'Quiet riot',
#  'Quavo',
#  'Queensryche',
#  'Quad City Djs',
#  'Queen Latifah',
#  'Quincy Jones',
#  'Queen Adreena',
#  'Quicksilver Messenger Service',
#  'Queers',
#  'Quint',
#  'Quicksand',
#  'Q Lazzarus',
#  'Quindon Tarver',
#  'Quaker City Nighthawks',
#  'Q-Tip',
#  'Qurat Ul Ain Balouch',
#  'Quentin Miller',
#  'Quantic',
#  'Quireboys',
#  'Queen Ifrica',
#  'Quietdrive',
#  'Quantum Jump',
#  'Que',
#  'Quebonafide',
#  'Question Mark & The Mysterians',
#  'Qntal',
#  'Quintessence',
#  'QUARTET NIGHT',
#  'Quinta Estacion',
#  'Quarter Flash',
#  'Quasimoto',
#  'Quorthon',
#  'Quarashi',
#  'Queeva',
#  'Quincy Punx',
#  'Quo Vadis',
#  'The Qemists',
#  'The Quakes',
#  'Queen Bee (女王蜂)',
#  'Q;indivi Starring Rin Oikawa',
#  'Q',
#  'QUEST PISTOLS SHOW',
#  'Rihanna',
#  'RENT',
#  'Ran',
#  'Rivermaya',
#  'Raffi',
#  'The Rolling Stones',
#  'Raju Punjabi',
#  'Red Hot Chili Peppers',
#  'Radiohead',
#  'Rahat Fateh Ali Khan',
#  'Rammstein',
#  'Rod Stewart',
#  'Ray Stevens',
#  'Race',
#  'Rascal Flatts',
#  'Ray Charles',
#  'Regine Velasquez',
#  'Rocky Horror Picture Show',
#  'Roy Orbison',
#  'R. Kelly',
#  'Russ',
#  'Rodney Carrington',
#  'The Righteous Brothers',
#  'Robbie Williams',
#  'Roan Ash',
#  'Rizky Febian',
#  'Reba McEntire',
#  'Ricky Dillard & New G',
#  'Rush',
#  'Rasmus Seebach',
#  'Roger Miller',
#  'Reed Foehl',
#  'Ramón Ayala',
#  'Randy Newman',
#  'Reshma',
#  'Rupert Holmes',
#  'Romeo Santos',
#  'Roberta Flack',
#  'The Ramones',
#  'REM',
#  'Ricky Martin',
#  'Roxette',
#  'Raisa',
#  'Ray LaMontagne',
#  'Robyn',
#  'Ram Jam',
#  'Sabyan Gambus',
#  'SpongeBob SquarePants',
#  'Sound Of Music',
#  'Sidhu Moose Wala',
#  'Shaun (숀)',
#  'SONU NIGAM',
#  'Sugar free',
#  'Sam Smith',
#  'Sia',
#  'Silent Sanctuary',
#  'Shawn Mendes',
#  'Selena Gomez',
#  'South Park',
#  'Shakira',
#  'Sarah Geronimo',
#  'SUD',
#  'STRBOI HUDZEN',
#  'Scooby Doo Theme Songs',
#  'Simon And Garfunkel',
#  'Spongecola',
#  'Sesame Street',
#  'Stephen Bishop',
#  'Shankar Mahadevan',
#  'Steven Universe',
#  'Songs For Children',
#  'Sabyan',
#  'Soundtrack',
#  'Sunanda Sharma',
#  'Shania Twain',
#  'Shanti Dope',
#  'Shreya Ghoshal',
#  'Snow Patrol',
#  'Samsons',
#  'Sam Concepcion',
#  'Stevie Wonder',
#  'Sharry Maan',
#  'Soulja Boy',
#  'Sandrina',
#  'The Smashing Pumpkins',
#  'Santana',
#  'Selena',
#  'Snoop Dogg',
#  'Sade',
#  'System Of A Down',
#  'Simpsons',
#  'Taylor Swift',
#  'Tony Kakkar',
#  'Traditional',
#  'Twenty One Pilots',
#  'Train',
#  'The Weeknd',
#  'Toto',
#  'Tim McGraw',
#  'Tulus',
#  'Travis Greene',
#  'Travis Scott',
#  'Tina Turner',
#  'T.I.',
#  'Tasha Cobbs',
#  'Toni Gonzaga',
#  'T-Pain',
#  'Ted Gärdestad',
#  'Tangerine Kitty',
#  'The 1975',
#  'Tracy Chapman',
#  'Typecast',
#  'Tyga',
#  'Tv Theme',
#  'Tony Bennett',
#  'TLC',
#  'The Smiths',
#  'Usher',
#  'U2',
#  'Ungu',
#  'Unknown',
#  'Urban Dub',
#  'Ub40',
#  'Ulf Lundell',
#  'Usa For Africa',
#  'Udit Narayan',
#  'Ustad Rashid Khan',
#  'Uncle Kracker',
#  'Uriah Heep',
#  'Underworld',
#  'UpDharmaDown',
#  'Ulices Chaidez',
#  'Ultravox',
#  'Uma Mohan',
#  'Ufo',
#  'US Marine Corps',
#  'U. D. O.',
#  'Unni Menon',
#  'Umut Timur',
#  'Utopia',
#  'Utada Hikaru',
#  'The Used',
#  'Unwound',
#  'UGK',
#  'UAB gospel choir',
#  "Umphrey's McGee",
#  'Uncle Acid and the Deadbeats',
#  'UK Subs',
#  'Us the Duo',
#  'Uncle Tupelo',
#  'The Underdog Project',
#  'Unique',
#  'The Undertones',
#  'Umberto Tozzi',
#  'Undertaker',
#  'Uverworld',
#  'Ultra Nate',
#  'Unbekannt',
#  'Urban Life Worship',
#  'UnSun',
#  'Umosia',
#  'Unkle',
#  'Vanessa Hudgens',
#  'Van Morrison',
#  'Virzha',
#  'VeggieTales',
#  'Victorious Cast',
#  'Virgoun',
#  'Velasquez Regine',
#  'Van Halen',
#  'Vitas',
#  'Vera Lynn',
#  'Vance Joy',
#  'Vidya Vox',
#  'Vince Gill',
#  'Vineeth Sreenivasan',
#  'Veronica Maggio',
#  'Vybz Kartel',
#  'Vaya Con Dios',
#  'Victorious',
#  'The Vamps',
#  'Vampire Weekend',
#  'Victoria Justice',
#  'Vicki Yohe',
#  'Village People',
#  'Vengaboys',
#  'Vashawn Mitchell',
#  'The Verve',
#  'Vanessa Williams',
#  'Volbeat',
#  'Vincent Bohanan & the Sound of Victory',
#  'Vicente Fernandez',
#  'Volkan Konak',
#  'Vanilla Ice',
#  'Vanessa Carlton',
#  'Vivek - Mervin',
#  'Vishal Dadlani',
#  'Venom',
#  'Valens Richie',
#  'Villagers',
#  'Valli Frankie',
#  'The Vandals',
#  'V6',
#  'Van Der Graaf Generator',
#  'Violent Femmes',
#  'Vasco Rossi',
#  'The Velvet Underground',
#  'Westlife',
#  'We Three',
#  'WICKED CREW',
#  'Willie Nelson',
#  'Wizard Of Oz',
#  'Whitney Houston',
#  'Chorus of Winnie The Pooh',
#  'Westside Story',
#  'WWE',
#  '"Weird Al" Yankovic',
#  'Will Smith',
#  'Wiz Khalifa',
#  'William Mcdowell',
#  'william murphy',
#  'Waylon Jennings',
#  'Weezer',
#  'Wolfgang',
#  'Wanna One (워너원)',
#  'Widespread Panic',
#  'The Who',
#  'Widi Nugroho',
#  'Walter Hawkins',
#  'The White Stripes',
#  'will.i.am',
#  'Wham!',
#  'W.A.S.P.',
#  'Wang Guang Liang',
#  'Wanda Jackson',
#  'The White Buffalo',
#  'Warren Zevon',
#  'We the Kings',
#  'Wale',
#  'Wrestling',
#  'Ween',
#  '王力宏 (Wang Lee Hom)',
#  'Whitesnake',
#  "Why Don't We",
#  'Woody Guthrie',
#  'The Wolfe Tones',
#  'Within Temptation',
#  'Whiskey Myers',
#  'Whispers',
#  'Wu-Tang Clan',
#  'Wander Over Yonder',
#  'Walk The Moon',
#  'XXXTENTACION',
#  'Xavier Rudd',
#  'The Xx',
#  'Xavier Naidoo',
#  'X',
#  'XTC',
#  'X Ambassadors',
#  'X-Japan',
#  'Xandria',
#  'Xuxa',
#  'Xscape',
#  'XYLØ',
#  'Xzibit',
#  'Xeno & Oaklander',
#  '小潘潘 (Xiao Pan Pan)',
#  'X Factor (UK)',
#  'X-Treme',
#  'X crew',
#  'X-Perience',
#  'Xiu Xiu',
#  'Ximena Sarinana',
#  'X-Ray Spex',
#  'Xavier Omar',
#  'XXL',
#  'XOX',
#  'X-Pose',
#  'Xymox',
#  'X Factor (US)',
#  'xikidi',
#  'Xuitcasecity',
#  'Xentrix',
#  'Xiao Yu',
#  'Xiao Bing Chih (蕭秉治)',
#  'Xriz',
#  'Xana Toc Toc',
#  'XV',
#  'Xo Icy',
#  'XIII Stoleti',
#  'Xenia Ghali',
#  'Xasthur',
#  'Xenia Rubinos',
#  'Xmal Deutschland',
#  'x factor finalists',
#  'X-Ecutioners',
#  'XY&O',
#  'Xantos',
#  'Yeng Constantino',
#  'Yuvan Shankar Raja',
#  'Yo Yo Honey Singh',
#  'Yung Raja',
#  'YoungBoy Never Broke Again',
#  'YG',
#  'Yuna',
#  'Yasin Aydin',
#  'Yolanda Adams',
#  'Yes',
#  'Yngwie Malmsteen',
#  'Young Thug',
#  'Young Jeezy',
#  'Yusuf Islam',
#  'Ying Yang Twins',
#  'Yves Larock',
#  'Yo Gotti',
#  'Years & Years',
#  'Yush Rah',
#  'Ylvis',
#  'The Yogscast',
#  'Yelawolf',
#  'Yovie & Nuno',
#  'yeah yeah yeahs',
#  'Yoonmirae (윤미래)',
#  'Yellow Claw',
#  'Yanni',
#  'Yura Yunita',
#  'You+Me',
#  'Yiruma',
#  'Young The Giant',
#  'Yash Narvekar',
#  'YUI',
#  'Yello',
#  'Young Money',
#  'You Me At Six',
#  'Yoko Ono',
#  'Young Nudy',
#  'Yardbirds',
#  'Yuzu',
#  'Yelle',
#  'Yaz',
#  'Young Buck',
#  'Yoko Oginome',
#  'You',
#  'yugioh zexal',
#  'Zayn Malik',
#  'Zack Knight',
#  'Zac Efron',
#  'Zac Brown Band',
#  'Zaz',
#  'Zhavia Ward',
#  'Zia Quizon',
#  'ZZ Top',
#  'Zonke Dikana',
#  'Zedd',
#  'Ziynet Sali',
#  'Ziana Zain',
#  'Zee Avi',
#  'The Zombies',
#  'Zoe',
#  'Zara Larsson',
#  'Ziggy Marley',
#  'Zach Williams',
#  'ZAYN',
#  'Ziv Zaifman',
#  'Zara',
#  'Ziggy Alberts',
#  'Zach Callison',
#  'Zucchero',
#  'Zakk Wylde',
#  'Zendaya',
#  'Zacarias Ferreira',
#  'Zebra',
#  'Zandie Khumalo',
#  'Z-Ro',
#  'Zumba Fitness',
#  'Zooey Deschanel',
#  'Zhu',
#  'zeds dead',
#  'Zanda Zakuza',
#  'Zac Brown',
#  'Zero 7',
#  'Zager and Evans',
#  'Zonke',
#  'zain bhikha',
#  'Zizan Razak',
#  'Zé Neto e Cristiano',
#  'Z-FLO',
#  'Zero Assoluto',
#  'ZZ Ward',
#  'Zhane']

# %%
first_part = retrieved.loc[retrieved.artist.isin(artists_retrieved), :]
first_part
# Out:
#             artist                           song  \
# 0          6ix9ine                           FEFE
# 1          6ix9ine                           KEKE
# 2          6ix9ine                           TATI
# 3          6ix9ine                          BILLY
# 4          6ix9ine                          Gummo
# 5          6ix9ine                          GOTTI
# 6          6ix9ine                          Kooda
# 7          6ix9ine                          RONDO
# 8          6ix9ine                     Blood Walk
# 9          6ix9ine                  GUMMO (Remix)
# 10         6ix9ine                          MOOKY
# 11         6ix9ine                         DOOWEE
# 12         6ix9ine                           BUBA
# 13         6ix9ine                             93
# 14         6ix9ine                           KIKA
# 15         6ix9ine                           Dope
# 16         6ix9ine         WISH U NEVER DONE THAT
# 17         6ix9ine                        STOOPID
# 18         6ix9ine         International Gangstas
# 19         6ix9ine                        TIC TOC
# 20         6ix9ine                         ISLAND
# 21         6ix9ine                          WONDO
# 22         6ix9ine   Blood Walk (Plug Walk Remix)
# 23         6ix9ine                           MAMA
# 24         6ix9ine                           Scum
# 25         6ix9ine                     KICK ROCKS
# 26         6ix9ine                          DUMMY
# 27         6ix9ine                          KANGA
# 28         6ix9ine                          FEEFA
# 29         6ix9ine                           WAKA
# ...            ...                            ...
# 47934  The Animals             I Can't Believe it
# 47935  The Animals                    No John, No
# 47936  The Animals                      Man-Woman
# 47937  The Animals                   Help Me Girl
# 47938  The Animals                        Outcast
# 47939  The Animals        The Story Of Bo Diddley
# 47940  The Animals  I Just Wanna Make Love to You
# 47941  The Animals                   Blue Feeling
# 47942  The Animals           Love Is for All Time
# 47943  The Animals          Prisoner of the Light
# 47944  The Animals             Darkness, Darkness
# 47945  The Animals           I Believe To My Soul
# 47946  The Animals      Baby Let Me Take You Home
# 47947  The Animals              As the Crow Flies
# 47948  The Animals                   Big Boss Man
# 47949  The Animals   Night Time Is the Right Time
# 47950  The Animals  Gonna Send You Back To Walker
# 47951  The Animals                 Latino America
# 47952  The Animals                   Bury My Body
# 47953  The Animals   It's All Over Now, Baby Blue
# 47954  The Animals                        Hey Gyp
# 47955  The Animals                  I'm Mad Again
# 47956  The Animals           Sweet Little Sixteen
# 47957  The Animals           I Put a Spell on You
# 47958  The Animals          Just Can't Get Enough
# 47959  The Animals              The Immigrant Lad
# 47960  The Animals                       The Fool
# 47961  The Animals    Letter From the County Farm
# 47962  The Animals              Talkin' 'Bout You
# 47963  The Animals                 Crystal Nights
#
#                                                    album release_date genre  \
# 0                                              DUMMY BOY   2018-07-22   NaN
# 1                                  DAY69: Graduation Day   2018-01-14   NaN
# 2                DAY69: Graduation Day (Japanese Import)   2018-05-27   NaN
# 3                                  DAY69: Graduation Day   1417-06-12   NaN
# 4                                  DAY69: Graduation Day   2017-10-08   NaN
# 5                                  DAY69: Graduation Day   2018-04-10   NaN
# 6                                  DAY69: Graduation Day   2017-12-03   NaN
# 7                                  DAY69: Graduation Day   2018-02-22   NaN
# 8                                                    NaN   2018-06-22   NaN
# 9                                  DAY69: Graduation Day   2018-02-23   NaN
# 10                                 DAY69: Graduation Day   2018-02-23   NaN
# 11                                 DAY69: Graduation Day   2018-02-23   NaN
# 12                                 DAY69: Graduation Day   2018-02-23   NaN
# 13                                 DAY69: Graduation Day   2018-02-23   NaN
# 14                                             DUMMY BOY   2018-11-27   NaN
# 15                                                   NaN   2018-06-14   NaN
# 16                                                   NaN   2018-03-12   NaN
# 17                                             DUMMY BOY   2018-10-05   NaN
# 18                                          Torremolinos   2018-09-21   NaN
# 19                                             DUMMY BOY   2018-11-27   NaN
# 20                           2018 Album Release Calendar          NaN   NaN
# 21                                             DUMMY BOY   2018-11-27   NaN
# 22                                          2018 Wrapped          NaN   NaN
# 23                                             DUMMY BOY   2018-11-27   NaN
# 24                                                   NaN   2020-01-26   NaN
# 25                                                   NaN          NaN   NaN
# 26                                             DUMMY BOY   2018-11-27   NaN
# 27                                             DUMMY BOY   2018-11-27   NaN
# 28                                             DUMMY BOY   2018-11-27   NaN
# 29                                             DUMMY BOY   2018-11-27   NaN
# ...                                                  ...          ...   ...
# 47934                                 Animal Tracks (US)          NaN  Rock
# 47935  In Search of the Castaways (The Children of Ca...          NaN  Rock
# 47936                                    Winds of Change          NaN  Rock
# 47937                                         Animalisms          NaN  Rock
# 47938                                         Animalisms          NaN  Rock
# 47939                           The Animals (UK Version)          NaN  Rock
# 47940                                       #CRYFEST1988   2018-10-05  Rock
# 47941                           The Animals (US Version)          NaN  Rock
# 47942                                                Ark   1983-08-01  Rock
# 47943                               Twelve Years a Slave   1853-01-01  Rock
# 47944                                      No More Tears   2002-01-01  Rock
# 47945                                The Animals on Tour          NaN  Rock
# 47946                           The Animals (US Version)          NaN  Rock
# 47947               Before We Were So Rudely Interrupted          NaN  Rock
# 47948                                         Animalisms          NaN  Rock
# 47949                                                NaN   2019-05-26  Rock
# 47950                           The Animals (US Version)          NaN  Rock
# 47951                                                NaN          NaN  Rock
# 47952                           The Animals (UK Version)          NaN  Rock
# 47953               Before We Were So Rudely Interrupted          NaN  Rock
# 47954                                          Animalism          NaN  Rock
# 47955                           The Animals (US Version)          NaN  Rock
# 47956                                         Animalisms          NaN  Rock
# 47957                                         Animalisms          NaN  Rock
# 47958                                 Neighbourhood Plug   2018-11-28  Rock
# 47959                                    Every One of Us          NaN  Rock
# 47960               Before We Were So Rudely Interrupted          NaN  Rock
# 47961                                            Ulysses   1922-02-02  Rock
# 47962                           The Animals (US Version)          NaN  Rock
# 47963                                     Nobel Lectures   2011-12-07  Rock
#
#                                                   lyrics
# 0       It's fuckin' TR3YWAY! King of New York, looki...
# 1       Scum Gang! AM Nation   I be on the block, on ...
# 2       Hold up, let me get it started B.B. with the ...
# 3       That's my word, get up in they face Talk your...
# 4       Niggas iffy, uh, blicky got the stiffy, uh Go...
# 5       Got me a new Rollie (You can't even afford th...
# 6       Scum Gang!   Niggas runnin' out they mouth, b...
# 7       I'ma do my dance in this bih (I'ma do my danc...
# 8       Akademiks Music Suwoo! Gltt, brra, brra, brra...
# 9       Niggas iffy, uh, Blicky got the stiffy, uh Go...
# 10      Stomp that nigga out, stomp that nigga out (S...
# 11      Phosphate   Yeah, yeah, yeah, yeah, yeah, get...
# 12      Scum Gang! MJ Pharaoh.. Vi-Vice   Slumped up,...
# 13      Scum Gang!   Bang! Run up, kick the door Bang...
# 14      Bitch, we in the city on that hot shit Lookin...
# 15      There's a lot of haters out here So I gotta l...
# 16      Wish you never done that Wish you never broug...
# 17      Y'all already know it be the boy Yung Gordon ...
# 18        Squad! It's fuckin' TR3YWAY Farid Bang, wha...
# 19      Yung Lan on the track   Okay, tick tock, Aude...
# 20     4/1 Gavy NJ - People Said Break It Up EP - 4/4...
# 21      Scott Storch   Shorty, don't clap-back on the...
# 22     Drake - God's Plan XXXTENTACION - SAD! Post Ma...
# 23      Uh Murda on the beat so it's not nice!   Tiki...
# 24      I am Eduardo Molina Scum Gang   Pump to his c...
# 25      Ebenezer Yeah, I still hear those war cries G...
# 26      Daytrip took it to 10   I spent some days in ...
# 27      M-M-M-Murda   She want me, I ain't want her, ...
# 28      Trapped on one stop, served my own block, bou...
# 29      Catch an asthma attack, the way we pull up on...
# ...                                                  ...
# 47934  Why am I lonely, why do I cry Am I gonna be a ...
# 47935  CHAPTER 16: A STARTLING DISCOVERY  It was a fr...
# 47936  Man, Woman, Desire, Love Love one another Can ...
# 47937  Girl have you ever been hungry So hungry that ...
# 47938  Girl, what have I done? For you to mistreat me...
# 47939  Now let's hear the story of Bo Diddley And the...
# 47940  Oh yes...It's about that time...AELA. Breakfas...
# 47941  Sit here and wonder what am I so blue Is it be...
# 47942  Were you and I just an overnight sensation An ...
# 47943  WILEY DISREGARDS THE COUNSELS OF AUNT PHEBE AN...
# 47944   Into the night I've got to go That's when the...
# 47945  One of these days and it won't be long Youre g...
# 47946  Baby can I take you home Baby let me take you ...
# 47947  As the crow flies, baby Will I ain't so far fr...
# 47948  Big boss man Can you hear me when I call Big b...
# 47949   Sippin Tropicana by the bay-ay And by the way...
# 47950  You had nothin' when I met you baby But look w...
# 47951  Michael Pollan: The way we eat has changed mor...
# 47952   Bury my body Lord, I don't care where they......
# 47953  You must leave now, take what you need, you th...
# 47954  I'll buy you a Chevrolet, I'll buy you a Chevr...
# 47955  I had a friend one time, at least I thought he...
# 47956  They're really rockin' in Boston In Pittsburgh...
# 47957  I put a spell on you, because you're mine You'...
# 47958    Look, Allot of people talking’ this and that...
# 47959  And here I sit with a tear in my eye, the wate...
# 47960  Gather round me buddies Hold your glasses high...
# 47961  I was just passing the time of day with old Tr...
# 47962  Ah ah ah ah da da dam da Ah ah ah da dam da da...
# 47963  A Programme of Texts by Tomas TranströmerProgr...
#
# [12886 rows x 6 columns]

# %%
first_part.to_csv("/Users/lucamasserano/Desktop/BOCCONI/nlp/final_project/lyrics_project/first_part.csv", index=False)

# %%
second_part = retrieved.loc[~retrieved.artist.isin(artists_retrieved), :]
second_part
# Out:
#                 artist                                          song album  \
# 12453  Eros Ramazzotti                               Fuoco Nel Fuoco   NaN
# 12454  Eros Ramazzotti                                  Parla Con Me   NaN
# 12455  Eros Ramazzotti                               I Belong To You   NaN
# 12456  Eros Ramazzotti                                      L'aurora   NaN
# 12457  Eros Ramazzotti                                  Un' Altra Te   NaN
# 12458  Eros Ramazzotti                                 Pi Bella Cosa   NaN
# 12459  Eros Ramazzotti                       Se Bastasse Una Canzone   NaN
# 12460  Eros Ramazzotti                         Una Storia Importante   NaN
# 12461  Eros Ramazzotti                                Non Siamo Soli   NaN
# 12462  Eros Ramazzotti                                Terra Promessa   NaN
# 12463  Eros Ramazzotti                                      Musica è   NaN
# 12464  Eros Ramazzotti                                     Adesso Tu   NaN
# 12465  Eros Ramazzotti                           L'ombra Del Gigante   NaN
# 12466  Eros Ramazzotti                              Quanto Amore Sei   NaN
# 12467  Eros Ramazzotti                                     Solo Ieri   NaN
# 12468  Eros Ramazzotti                                   Controvento   NaN
# 12469  Eros Ramazzotti                             Un Attimo di Pace   NaN
# 12470  Eros Ramazzotti                               Canzone Per Lei   NaN
# 12471  Eros Ramazzotti                               Cose Della Vita   NaN
# 12472  Eros Ramazzotti  Cose Della Vita (can't Stop Thinking Of You)   NaN
# 12473  Eros Ramazzotti                               Fino All'Estasi   NaN
# 12474  Eros Ramazzotti                                      Yo Sin T   NaN
# 12475  Eros Ramazzotti                       Lo Spirito Degli Alberi   NaN
# 12476  Eros Ramazzotti                     Amarti è L'immenso Per Me   NaN
# 12477  Eros Ramazzotti                                  Amore Contro   NaN
# 12478  Eros Ramazzotti                                      Bucaneve   NaN
# 12479  Eros Ramazzotti                                 Cuori Agitati   NaN
# 12480  Eros Ramazzotti                                   Solo Con Te   NaN
# 12481  Eros Ramazzotti                             Per Me Per Sempre   NaN
# 12482  Eros Ramazzotti                                 Voglio Volare   NaN
# ...                ...                                           ...   ...
# 59959          ZZ Ward                            Charlie Aint' Home   NaN
# 59960          ZZ Ward                                  She Ain't Me   NaN
# 59961          ZZ Ward                                      The Deep   NaN
# 59962          ZZ Ward                                  Help Me Mama   NaN
# 59963          ZZ Ward                                Last Love Song   NaN
# 59964          ZZ Ward                                      Criminal   NaN
# 59965          ZZ Ward                                       Hold On   NaN
# 59966          ZZ Ward                         Till The Casket Drops   NaN
# 59967          ZZ Ward                               Blue Eyes Blind   NaN
# 59968          ZZ Ward                        If U Stayed [Explicit]   NaN
# 59969          ZZ Ward                                    Cryin Wolf   NaN
# 59970          ZZ Ward                                        Domino   NaN
# 59971          ZZ Ward                                        Rescue   NaN
# 59972          ZZ Ward                                          Home   NaN
# 59973          ZZ Ward                                   Lil' Darlin   NaN
# 59974          ZZ Ward                                   Let It Burn   NaN
# 59975          ZZ Ward               365 Days (Blended Babies Remix)   NaN
# 59976          ZZ Ward                             If I Could Be Her   NaN
# 59977          ZZ Ward                                  Save My Life   NaN
# 59978          ZZ Ward                 Love 3X (Robert DeLong Remix)   NaN
# 59979          ZZ Ward                                       Overdue   NaN
# 59980            Zhane               Everything Happens For A Reason   NaN
# 59981            Zhane                                     Hey Mr Dj   NaN
# 59982            Zhane                                         Crush   NaN
# 59983            Zhane                                  Request Line   NaN
# 59984            Zhane                                  Groove Thang   NaN
# 59985            Zhane                                      La La La   NaN
# 59986            Zhane                                  By Your Side   NaN
# 59987            Zhane                                   Rendez-Vous   NaN
# 59988            Zhane                           Sweet Taste Of Love   NaN
#
#       release_date    genre lyrics
# 12453          NaN      Pop    NaN
# 12454          NaN      Pop    NaN
# 12455          NaN      Pop    NaN
# 12456          NaN      Pop    NaN
# 12457          NaN      Pop    NaN
# 12458          NaN      Pop    NaN
# 12459          NaN      Pop    NaN
# 12460          NaN      Pop    NaN
# 12461          NaN      Pop    NaN
# 12462          NaN      Pop    NaN
# 12463          NaN      Pop    NaN
# 12464          NaN      Pop    NaN
# 12465          NaN      Pop    NaN
# 12466          NaN      Pop    NaN
# 12467          NaN      Pop    NaN
# 12468          NaN      Pop    NaN
# 12469          NaN      Pop    NaN
# 12470          NaN      Pop    NaN
# 12471          NaN      Pop    NaN
# 12472          NaN      Pop    NaN
# 12473          NaN      Pop    NaN
# 12474          NaN      Pop    NaN
# 12475          NaN      Pop    NaN
# 12476          NaN      Pop    NaN
# 12477          NaN      Pop    NaN
# 12478          NaN      Pop    NaN
# 12479          NaN      Pop    NaN
# 12480          NaN      Pop    NaN
# 12481          NaN      Pop    NaN
# 12482          NaN      Pop    NaN
# ...            ...      ...    ...
# 59959          NaN  Hip-Hop    NaN
# 59960          NaN  Hip-Hop    NaN
# 59961          NaN  Hip-Hop    NaN
# 59962          NaN  Hip-Hop    NaN
# 59963          NaN  Hip-Hop    NaN
# 59964          NaN  Hip-Hop    NaN
# 59965          NaN  Hip-Hop    NaN
# 59966          NaN  Hip-Hop    NaN
# 59967          NaN  Hip-Hop    NaN
# 59968          NaN  Hip-Hop    NaN
# 59969          NaN  Hip-Hop    NaN
# 59970          NaN  Hip-Hop    NaN
# 59971          NaN  Hip-Hop    NaN
# 59972          NaN  Hip-Hop    NaN
# 59973          NaN  Hip-Hop    NaN
# 59974          NaN  Hip-Hop    NaN
# 59975          NaN  Hip-Hop    NaN
# 59976          NaN  Hip-Hop    NaN
# 59977          NaN  Hip-Hop    NaN
# 59978          NaN  Hip-Hop    NaN
# 59979          NaN  Hip-Hop    NaN
# 59980          NaN      R&B    NaN
# 59981          NaN      R&B    NaN
# 59982          NaN      R&B    NaN
# 59983          NaN      R&B    NaN
# 59984          NaN      R&B    NaN
# 59985          NaN      R&B    NaN
# 59986          NaN      R&B    NaN
# 59987          NaN      R&B    NaN
# 59988          NaN      R&B    NaN
#
# [47103 rows x 6 columns]

# %%
lyrics = retrieve_lyrics(second_part, api, output_filename="second_part", avoid_artists=artists_retrieved)
lyrics.shape
# Out:
# Timeout raised and caught:al songs: 1168
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 2464
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 3503
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Timeout raised and caught:al songs: 3633
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Lyrics retrieved: 3240 Total songs: 3853
